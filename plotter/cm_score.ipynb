# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import scienceplots

plt.style.use(['science', 'ieee'])
plt.rcParams["text.usetex"] = False

# %%
# The data is saved from the FL fitting but manually copied here
f1s = [0.06135149008690503, 0.06618090943789504, 0.13059561257172564, 0.686168633257732, 0.9358303562644267, 0.9429907594682698, 0.9312643486010495, 0.9294178328710867, 0.9275768610941336, 0.9320125411629087, 0.9210310047164968]
aucs = [0.5796778097972716, 0.6006771963731186, 0.7193629590061486, 0.8324290150518567, 0.9859023234952802, 0.9888693596402086, 0.9729381796712955, 0.9660134855499921, 0.9633640537568228, 0.9679223312268193, 0.9585919395647554]

# %%
# Plot the F1 score
plt.plot(np.arange(0, 11, 1), f1s, marker='^', linewidth=0.5, markersize=2, color='green')
plt.xlabel('Training Rounds')
plt.ylabel('F1 score')
plt.show()

# %%
# Plot the AUC

plt.plot(np.arange(0, 11, 1), aucs, marker='^', linewidth=0.5, markersize=2, color='green')
plt.xlabel('Training Rounds')
plt.ylabel('AUC')
plt.show()
